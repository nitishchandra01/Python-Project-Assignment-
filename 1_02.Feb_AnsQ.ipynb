# %% [raw]
# 1Q. Explain with an example each when to use a for loop and a while loop.
#
# Ans:-> A for loop is typically used when you know the number of times you need to iterate through a block of code. It's useful when you want to execute the same code multiple times with different values. For instance, let's say you have a list of numbers and you want to print out each number in the list. You can use a for loop to iterate over the list:
#
# numbers = [1, 2, 3, 4, 5]
# for num in numbers:
#     print(num)
#
# In this example, the for loop iterates through the numbers list and assigns each number to the variable num. The print function is then called with num as its argument, printing out each number in the list.
#
# On the other hand, a while loop is used when you want to execute a block of code repeatedly until a certain condition is met. This type of loop is useful when you don't know in advance how many times you need to iterate through the code. For example, let's say you want to keep adding numbers to a list until the sum of the numbers in the list is greater than 100. You can use a while loop to do this:
#
# numbers = []
# total = 0
# while total < 100:
#     num = int(input("Enter a number: "))
#     numbers.append(num)
#     total = sum(numbers)
# print(numbers)
#
# In this example, the while loop keeps prompting the user to enter a number and adding that number to the numbers list until the sum of the numbers in the list is greater than 100. The sum function is used to calculate the total sum of the numbers in the list. Once the condition in the while loop is met, the loop stops and the numbers list is printed out.

# %% [raw]
# 2Q. Write a python program to print the sum and product of the first 10 natural numbers using for
# and while loop.
#
# Ans:-> Here's a Python program that prints the sum and product of the first 10 natural numbers using both for and while loops:
#
# Using For Loop:
# # Calculating sum and product of first 10 natural numbers using for loop
#
# sum = 0
# product = 1
#
# for i in range(1, 11):
#     sum += i
#     product *= i
#
# print("Sum of first 10 natural numbers is:", sum)
# print("Product of first 10 natural numbers is:", product
#
#
# Using While Loop:
# # Calculating sum and product of first 10 natural numbers using while loop
#
# sum = 0
# product = 1
# count = 1
#
# while count <= 10:
#     sum += count
#     product *= count
#     count += 1
#
# print("Sum of first 10 natural numbers is:", sum)
# print("Product of first 10 natural numbers is:", product)
#
#
# Both of these programs output the same results:
#
# Sum of first 10 natural numbers is: 55
# Product of first 10 natural numbers is: 3628800

# %% [raw]
# 3Q. Create a python program to compute the electricity bill for a household. The per-unit charges in rupees are as follows: For the first 100 units, the user will be charged Rs. 4.5 per
# unit, for the next 100 units, the user will be charged Rs. 6 per unit, and for the next 100 units, the user will
# be charged Rs. 10 per unit, After 300 units and above the user will be charged Rs. 20 per unit.
# You are required to take the units of electricity consumed in a month from the user as input.
# Your program must pass this test case: when the unit of electricity consumed by the user in a month is
# 310, the total electricity bill should be 2250
#
# Ans:-> Here's a Python program to compute the electricity bill for a household based on the units consumed in a month:
#
# # Ask the user to enter the units of electricity consumed in a month
# units = int(input("Enter the number of units consumed: "))
#
# # Initialize the bill amount to 0
# bill_amount = 0
#
# # Calculate the bill amount based on the per-unit charges
# if units <= 100:
#     bill_amount = units * 4.5
# elif units <= 200:
#     bill_amount = (100 * 4.5) + ((units - 100) * 6)
# elif units <= 300:
#     bill_amount = (100 * 4.5) + (100 * 6) + ((units - 200) * 10)
# else:
#     bill_amount = (100 * 4.5) + (100 * 6) + (100 * 10) + ((units - 300) * 20)
#
# # Print the total bill amount
# print("Total electricity bill: Rs. ", bill_amount)
#
# This program takes the units of electricity consumed as input from the user and calculates the bill amount based on the per-unit charges mentioned in the problem statement. It uses a series of if-else statements to determine which charging slab the user falls under and calculates the bill amount accordingly. Finally, it prints the total bill amount.

# %% [raw]
# 4Q. Create a list of numbers from 1 to 100. Use for loop and while loop to calculate the cube of each
# number and if the cube of that number is divisible by 4 or 5 then append that number in a list and print
# that list.
#
# Ans:-> Here's how you can create a list of numbers from 1 to 100 and calculate the cube of each number using a for loop:
#
# cubes = []
# for i in range(1, 101):
#     cube = i ** 3
#     if cube % 4 == 0 or cube % 5 == 0:
#         cubes.append(cube)
#
# print(cubes)
# And here's how you can achieve the same thing using a while loop:
#
# cubes = []
# i = 1
# while i <= 100:
#     cube = i ** 3
#     if cube % 4 == 0 or cube % 5 == 0:
#         cubes.append(cube)
#     i += 1
#
# print(cubes)
# Both of these programs will print a list of all the cubes from 1 to 100 that are divisible by either 4 or 5.

# %% [raw]
# Here's a Python program to filter and count the vowels in the given string:
#
# string = "I want to become a data scientist"
#
# # Define a function to filter and count vowels
# def count_vowels(s):
#     vowels = "aeiouAEIOU"
#     count = 0
#     for char in s:
#         if char in vowels:
#             count += 1
#     return count
#
# # Call the function with the given string
# vowel_count = count_vowels(string)
#
# # Print the vowel count
# print("The number of vowels in the string is:", vowel_count)
#
# Output:
# The number of vowels in the string is: 12
#
# Explanation:
# The count_vowels() function takes a string as input and uses a for loop to iterate over each character in the string. If the character is a vowel, the function increments the count variable. After all the characters have been processed, the function returns the count of vowels.
#
# The function is called with the given string, and the returned vowel count is printed to the console. In this case, there are 12 vowels in the string.
